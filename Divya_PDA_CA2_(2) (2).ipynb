# %%
import requests
import json
import pandas as pd

# %%
url='https://api.myhome.ie/search'

# %%
data='{"ApiKey":"5f4bc74f-8d9a-41cb-ab85-a1b7cfc86622","CorrelationId":"a8fa2f21-994c-418b-852f-0c14260f93d4","RequestTypeId":2,"RequestVerb":"POST","Endpoint":"https://api.myhome.ie/search","Page":%i,"PageSize":20,"SortColumn":2,"SortDirection":2,"SearchRequest":{"IsBackendSearch":false,"SkipSearchIndex":false,"IsGroupPrivateSearch":false,"IsSaleAgreed":false,"IsSold":false,"IsAuction":false,"IsBoundsSearch":false,"UseFreeTextSearchForKeywords":false,"SearchContent":false,"PropertyIds":[],"GroupIds":[],"ChannelIds":[1],"PropertyTypeIds":[97],"PropertyClassIds":[1],"PropertyStatusIds":[2,12],"SaleTypeIds":[],"FeatureTypeIds":[],"RegionId":2168,"LocalityIds":[],"LocalityNames":[],"NegotiatorIds":[],"SolicitorIds":[],"BuyerSolicitorIds":[],"VendorSolicitorIds":[],"TransferedByUserIds":[],"RowStatusIds":[2],"EnergyRatings":[],"Polygons":[],"Destinations":[],"Tags":[],"PrivateTags":[],"PreSixtyThree":false,"IsActive":true,"HasPhotos":false,"PriceFrequency":"Monthly"}}'

# %%
headers={'accept': 'application/json, text/plain, */*',
'accept-encoding': 'gzip, deflate, br',
'accept-language': 'en-US,en-IN;q=0.9,en;q=0.8',
'content-length': '971',
'content-type': 'application/json',
'origin': 'https://www.myhome.ie',
'referer': 'https://www.myhome.ie/',
'sec-ch-ua': '"Not?A_Brand";v="8", "Chromium";v="108", "Google Chrome";v="108"',
'sec-ch-ua-mobile': '?1',
'sec-ch-ua-platform': '"Android"',
'sec-fetch-dest': 'empty',
'sec-fetch-mode': 'cors',
'sec-fetch-site': 'same-site',
'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Mobile Safari/537.36;'}

# %%
r=requests.post(url,data=data,headers=headers)
r
# Out:
# <Response [200]>

# %%
r.content
1
# Out:
# 1

# %%
#create a formatted string of the Python JSON object
def jprint(obj):
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# %%
rdata=json.loads(r.content)

# %%
SearchResults=rdata['SearchResults']
len(SearchResults)
# Out:
# 20

# %%
# Range of search resultcount 
l=[]
for i in range(0,rdata['ResultCount'],20):
    SearchResults=json.loads(requests.post(url,data=(data%i),headers=headers).content)['SearchResults']
    l=l+SearchResults

# %%
len(l)
# Out:
# 520

# %%
#data normalization 
df=pd.json_normalize(l)
df.head()
# Out:
#    PropertyId  GroupId                        RefreshedOn  \
# 0     4662072     6330  2022-12-17T13:30:26.9170000+00:00
# 1     4608915     9213  2022-12-17T13:12:26.9070000+00:00
# 2     4660963     6330  2022-12-17T13:03:26.2770000+00:00
# 3     4458621    10843  2022-12-17T13:03:20.4170000+00:00
# 4     4578759     5649  2022-12-17T12:54:15.8170000+00:00
#
#                                          Address GroupPhoneNumber  \
# 0                         Coolbane, Garrettstown
# 1                         Innishannon, Cove Road
# 2                          19 Saint Multose Walk
# 3    House Type A. Castleview, Williamstown Road
# 4  25 Our Lady's Place,Naas,Co. Kildare,W91 RH6A
#
#                          GroupEmail                          GroupName  \
# 0  jamesmurphyauctioneers@gmail.com     James Murphy & Co. Auctioneers
# 1       info@griffinauctioneers.com                Griffin Auctioneers
# 2  jamesmurphyauctioneers@gmail.com     James Murphy & Co. Auctioneers
# 3       info@dngreidandcoppinger.ie               DNG Reid & Coppinger
# 4                      info@sfor.ie  Sherry FitzGerald O'Reilly (Naas)
#
#                                    GroupAddress  \
# 0           14 Pearse Street, Kinsale, Co. Cork
# 1         7 Main Street, Tramore, Co. Waterford
# 2           14 Pearse Street, Kinsale, Co. Cork
# 3                 No. 52 High Street, Waterford
# 4  Equity House, Main Street, Naas, Co. Kildare
#
#            GroupUrlSlugIdentifier                      CreatedOnDate  ...  \
# 0     james-murphy-co-auctioneers  2022-11-18T10:52:50.8730000+00:00  ...
# 1      michael-griffin-auctioneer  2022-06-30T11:02:18.1630000+01:00  ...
# 2     james-murphy-co-auctioneers  2022-11-14T17:19:50.5070000+00:00  ...
# 3     dng-thomas-reid-auctioneers  2020-09-30T08:49:26.6070000+01:00  ...
# 4  sherry-fitzgerald-oreilly-naas  2022-03-22T17:27:44.3530000+00:00  ...
#
#   LatestPriceChangeString                                Negotiator.ImageUrl  \
# 0                     NaN                                                NaN
# 1  €55,000 on 21st Nov 22  https://photos-a.propertyimages.ie/users/0/4/5...
# 2                     NaN                                                NaN
# 3  €10,000 on 25th Jul 22                                                NaN
# 4                     NaN                                                NaN
#
#    Negotiator.Email Negotiator.JobTitle NewHomeSizeString  \
# 0               NaN                 NaN               NaN
# 1               NaN                 NaN               NaN
# 2               NaN                 NaN               NaN
# 3               NaN                 NaN               NaN
# 4    cathal@sfor.ie                 NaN               NaN
#
#   CustomData.AssociatedArticleUrl JointAgentGroupName JointAgentGroupAddress  \
# 0                             NaN                 NaN                    NaN
# 1                             NaN                 NaN                    NaN
# 2                             NaN                 NaN                    NaN
# 3                             NaN                 NaN                    NaN
# 4                             NaN                 NaN                    NaN
#
#   JointAgentGroupUrl CustomData.JointAgentGroupId
# 0                NaN                          NaN
# 1                NaN                          NaN
# 2                NaN                          NaN
# 3                NaN                          NaN
# 4                NaN                          NaN
#
# [5 rows x 84 columns]

# %%
df.dtypes
# Out:
# PropertyId                           int64
# GroupId                              int64
# RefreshedOn                         object
# Address                             object
# GroupPhoneNumber                    object
#                                     ...
# CustomData.AssociatedArticleUrl     object
# JointAgentGroupName                 object
# JointAgentGroupAddress              object
# JointAgentGroupUrl                  object
# CustomData.JointAgentGroupId       float64
# Length: 84, dtype: object

# %% [markdown]
# # Dropping unwanted columns from dataframe

# %%
df=pd.json_normalize(l)
df.drop(['LatestPriceChangeString','SizeStringFeet','CustomData.AssociatedArticleUrl','NewHomeSizeString','JointAgentGroupName','JointAgentGroupAddress','JointAgentGroupUrl','CustomData.JointAgentGroupId', 'GroupPhoneNumber','Negotiator.ImageUrl','Negotiator.JobTitle', 'CustomData.PromotionalSnippet', 'Negotiator.NegotiatorId','Negotiator.Name',   'Negotiator.Phone', 'Negotiator.Email', 'CustomData.DevelopmentLogoBgColour', 'AdditionalLogoUrls',  'RelatedPropertiesTotal',   'CustomData.HidePostCode',  'CustomData.RelatedPropertyIDs','CustomData.IsMyHomePassport', 'TravelTimes', 'AuctionList',  'Location.lat', 'Location.lon', 'BrochureUrl', 'SeoUrl',   'PhotoCount',   'MainPhoto',    'MainPhotoWeb', 'Photos', 'IsNew','IsSaleAgreed','GroupLogoBgColor','GroupLogoUrl','GroupPremiumLogoUrl','GroupPremiumJointLogoUrl','GroupRectangularLogoUrl','JointGroupRectangularLogoUrl','GroupUrl','IsPremiumAd','IsBuildToRent','IsBuildToRentDevelopment','IsPrivateLandlord','IsBrandBooster','GroupUrlSlugIdentifier',  'SaleTypeId','IsFavourite','HasVideos','HasWebP','IsMappedAccurately','IsTopSpot','BedsString','PriceAsString','PriceChangeIsIncrease','DisplayAddress','PropertyClassId','PropertyClass','PropertyClassUrlSlug','BathString','BerRating','EnergyRatingMediaPath','OrderedDisplayAddress','SeoDisplayAddress', 'BrochureMap.longitude','BrochureMap.latitude','SizeStringMeters', 'OpenViewings','VirtualViewings'],axis=1,inplace=True)

# %%
df
# Out:
#      PropertyId  GroupId                        RefreshedOn  \
# 0       4662072     6330  2022-12-17T13:30:26.9170000+00:00
# 1       4608915     9213  2022-12-17T13:12:26.9070000+00:00
# 2       4660963     6330  2022-12-17T13:03:26.2770000+00:00
# 3       4458621    10843  2022-12-17T13:03:20.4170000+00:00
# 4       4578759     5649  2022-12-17T12:54:15.8170000+00:00
# ..          ...      ...                                ...
# 515     4527615     9433  2021-09-06T16:26:04.0000000+01:00
# 516     4527548     6598  2021-09-06T14:48:28.8300000+01:00
# 517     4527554   387550  2021-09-06T14:41:44.8900000+01:00
# 518     4527402   259812  2021-09-04T02:26:32.4770000+01:00
# 519     4450449   366768  2021-09-03T17:05:44.1230000+01:00
#
#                                                Address  \
# 0                               Coolbane, Garrettstown
# 1                               Innishannon, Cove Road
# 2                                19 Saint Multose Walk
# 3          House Type A. Castleview, Williamstown Road
# 4        25 Our Lady's Place,Naas,Co. Kildare,W91 RH6A
# ..                                                 ...
# 515                     Main Street Headford Co Galway
# 516     Saint Christopher's, Riverbank, Ringmahon Road
# 517                      Coorycommane, Coomhola Bridge
# 518  Dun Gaoithe,Sheskinerone,Dungloe,Co Donegal,F9...
# 519                120 Ashdrive, Westwood, Ballea Road
#
#                            GroupEmail                           GroupName  \
# 0    jamesmurphyauctioneers@gmail.com      James Murphy & Co. Auctioneers
# 1         info@griffinauctioneers.com                 Griffin Auctioneers
# 2    jamesmurphyauctioneers@gmail.com      James Murphy & Co. Auctioneers
# 3         info@dngreidandcoppinger.ie                DNG Reid & Coppinger
# 4                        info@sfor.ie   Sherry FitzGerald O'Reilly (Naas)
# ..                                ...                                 ...
# 515   info@vincentwalshauctioneers.ie           Vincent Walsh Auctioneers
# 516          info@barryauctioneers.ie         Barry Auctioneers & Valuers
# 517      info@bowdensestateagents.com               Bowdens Estate Agents
# 518                   property@sfr.ie            Sherry FitzGerald Rainey
# 519             info@michaelpigott.ie  Michael Pigott Auctioneer & Valuer
#
#                                      GroupAddress  \
# 0             14 Pearse Street, Kinsale, Co. Cork
# 1           7 Main Street, Tramore, Co. Waterford
# 2             14 Pearse Street, Kinsale, Co. Cork
# 3                   No. 52 High Street, Waterford
# 4    Equity House, Main Street, Naas, Co. Kildare
# ..                                            ...
# 515     St George's Square , Headford, Co. Galway
# 516     77 South Mall, Cork City Centre, Co. Cork
# 517  Summerhill, Market Street, Bantry, Co. Cork
# 518         45 Port Road, Letterkenny, Co Donegal
# 519            Main Street, Carrigaline, Co. Cork
#
#                          CreatedOnDate                        ActivatedOn  \
# 0    2022-11-18T10:52:50.8730000+00:00  2022-11-18T10:57:45.3430000+00:00
# 1    2022-06-30T11:02:18.1630000+01:00  2022-06-30T11:23:05.9500000+01:00
# 2    2022-11-14T17:19:50.5070000+00:00  2022-11-14T17:26:14.4500000+00:00
# 3    2020-09-30T08:49:26.6070000+01:00  2020-09-30T08:54:29.5600000+01:00
# 4    2022-03-22T17:27:44.3530000+00:00  2022-03-22T17:28:57.6370000+00:00
# ..                                 ...                                ...
# 515  2021-09-06T16:22:35.7870000+01:00  2021-09-06T16:26:04.0000000+01:00
# 516  2021-09-06T14:28:25.4670000+01:00  2021-09-06T14:48:28.8300000+01:00
# 517  2021-09-06T14:39:49.6530000+01:00  2021-09-06T14:41:44.8900000+01:00
# 518  2021-09-04T02:25:16.3800000+01:00  2021-09-04T02:26:32.4770000+01:00
# 519  2020-08-27T12:47:26.6700000+01:00  2021-09-03T17:05:44.1230000+01:00
#
#      IsActive       id PropertyStatus          PropertyType  \
# 0        True  4662072        ForSale        Detached House
# 1        True  4608915        ForSale        Detached House
# 2        True  4660963        ForSale  End of Terrace House
# 3        True  4458621        ForSale        Detached House
# 4        True  4578759        ForSale   Semi-Detached House
# ..        ...      ...            ...                   ...
# 515      True  4527615        ForSale             Townhouse
# 516      True  4527548        ForSale        Detached House
# 517      True  4527554        ForSale        Detached House
# 518      True  4527402        ForSale              Bungalow
# 519      True  4450449        ForSale   Semi-Detached House
#
#                   Negotiator.WebSite
# 0         https://www.jm-estates.com
# 1                                NaN
# 2         https://www.jm-estates.com
# 3                                NaN
# 4         https://www.sherryfitz.ie/
# ..                               ...
# 515                              NaN
# 516  http://www.barryauctioneers.ie/
# 517                              NaN
# 518                              NaN
# 519      http://www.michaelpigott.ie
#
# [520 rows x 14 columns]

# %%
df.drop(['id','Negotiator.WebSite'],axis=1,inplace=True)
df
# Out:
#      PropertyId  GroupId                        RefreshedOn  \
# 0       4662072     6330  2022-12-17T13:30:26.9170000+00:00
# 1       4608915     9213  2022-12-17T13:12:26.9070000+00:00
# 2       4660963     6330  2022-12-17T13:03:26.2770000+00:00
# 3       4458621    10843  2022-12-17T13:03:20.4170000+00:00
# 4       4578759     5649  2022-12-17T12:54:15.8170000+00:00
# ..          ...      ...                                ...
# 515     4527615     9433  2021-09-06T16:26:04.0000000+01:00
# 516     4527548     6598  2021-09-06T14:48:28.8300000+01:00
# 517     4527554   387550  2021-09-06T14:41:44.8900000+01:00
# 518     4527402   259812  2021-09-04T02:26:32.4770000+01:00
# 519     4450449   366768  2021-09-03T17:05:44.1230000+01:00
#
#                                                Address  \
# 0                               Coolbane, Garrettstown
# 1                               Innishannon, Cove Road
# 2                                19 Saint Multose Walk
# 3          House Type A. Castleview, Williamstown Road
# 4        25 Our Lady's Place,Naas,Co. Kildare,W91 RH6A
# ..                                                 ...
# 515                     Main Street Headford Co Galway
# 516     Saint Christopher's, Riverbank, Ringmahon Road
# 517                      Coorycommane, Coomhola Bridge
# 518  Dun Gaoithe,Sheskinerone,Dungloe,Co Donegal,F9...
# 519                120 Ashdrive, Westwood, Ballea Road
#
#                            GroupEmail                           GroupName  \
# 0    jamesmurphyauctioneers@gmail.com      James Murphy & Co. Auctioneers
# 1         info@griffinauctioneers.com                 Griffin Auctioneers
# 2    jamesmurphyauctioneers@gmail.com      James Murphy & Co. Auctioneers
# 3         info@dngreidandcoppinger.ie                DNG Reid & Coppinger
# 4                        info@sfor.ie   Sherry FitzGerald O'Reilly (Naas)
# ..                                ...                                 ...
# 515   info@vincentwalshauctioneers.ie           Vincent Walsh Auctioneers
# 516          info@barryauctioneers.ie         Barry Auctioneers & Valuers
# 517      info@bowdensestateagents.com               Bowdens Estate Agents
# 518                   property@sfr.ie            Sherry FitzGerald Rainey
# 519             info@michaelpigott.ie  Michael Pigott Auctioneer & Valuer
#
#                                      GroupAddress  \
# 0             14 Pearse Street, Kinsale, Co. Cork
# 1           7 Main Street, Tramore, Co. Waterford
# 2             14 Pearse Street, Kinsale, Co. Cork
# 3                   No. 52 High Street, Waterford
# 4    Equity House, Main Street, Naas, Co. Kildare
# ..                                            ...
# 515     St George's Square , Headford, Co. Galway
# 516     77 South Mall, Cork City Centre, Co. Cork
# 517  Summerhill, Market Street, Bantry, Co. Cork
# 518         45 Port Road, Letterkenny, Co Donegal
# 519            Main Street, Carrigaline, Co. Cork
#
#                          CreatedOnDate                        ActivatedOn  \
# 0    2022-11-18T10:52:50.8730000+00:00  2022-11-18T10:57:45.3430000+00:00
# 1    2022-06-30T11:02:18.1630000+01:00  2022-06-30T11:23:05.9500000+01:00
# 2    2022-11-14T17:19:50.5070000+00:00  2022-11-14T17:26:14.4500000+00:00
# 3    2020-09-30T08:49:26.6070000+01:00  2020-09-30T08:54:29.5600000+01:00
# 4    2022-03-22T17:27:44.3530000+00:00  2022-03-22T17:28:57.6370000+00:00
# ..                                 ...                                ...
# 515  2021-09-06T16:22:35.7870000+01:00  2021-09-06T16:26:04.0000000+01:00
# 516  2021-09-06T14:28:25.4670000+01:00  2021-09-06T14:48:28.8300000+01:00
# 517  2021-09-06T14:39:49.6530000+01:00  2021-09-06T14:41:44.8900000+01:00
# 518  2021-09-04T02:25:16.3800000+01:00  2021-09-04T02:26:32.4770000+01:00
# 519  2020-08-27T12:47:26.6700000+01:00  2021-09-03T17:05:44.1230000+01:00
#
#      IsActive PropertyStatus          PropertyType
# 0        True        ForSale        Detached House
# 1        True        ForSale        Detached House
# 2        True        ForSale  End of Terrace House
# 3        True        ForSale        Detached House
# 4        True        ForSale   Semi-Detached House
# ..        ...            ...                   ...
# 515      True        ForSale             Townhouse
# 516      True        ForSale        Detached House
# 517      True        ForSale        Detached House
# 518      True        ForSale              Bungalow
# 519      True        ForSale   Semi-Detached House
#
# [520 rows x 12 columns]

# %%
df.dtypes
# Out:
# PropertyId         int64
# GroupId            int64
# RefreshedOn       object
# Address           object
# GroupEmail        object
# GroupName         object
# GroupAddress      object
# CreatedOnDate     object
# ActivatedOn       object
# IsActive            bool
# PropertyStatus    object
# PropertyType      object
# dtype: object

# %%
#Highest price property?
top5=df.sort_values('PropertyType',ascending=False,inplace=False, axis=0,ignore_index=True)
(top5.head(5))
# Out:
#    PropertyId  GroupId                        RefreshedOn  \
# 0     4642984    11103  2022-09-15T14:45:41.1900000+01:00
# 1     4616592     7137  2022-09-25T08:51:46.1370000+01:00
# 2     4635558     5689  2022-08-23T16:42:47.6770000+01:00
# 3     4553929   344399  2022-05-06T16:30:56.1970000+01:00
# 4     4647610     6124  2022-11-17T17:13:04.4000000+00:00
#
#                                       Address                GroupEmail  \
# 0                     Hampton Grace Park Road  anne@gallagherquigley.ie
# 1        20 Goldsmith's Avenue, Richmond Hill      info@jeremymurphy.ie
# 2                       26 Thomas Hand Street    info@sfcumiskykelly.ie
# 3                         12 Melville Terrace             info@imove.ie
# 4  4 Ballyclough Terrace, Ballycummin Village           info@rooneys.eu
#
#                           GroupName  \
# 0                 Gallagher Quigley
# 1        Jeremy Murphy & Associates
# 2  Sherry Fitzgerald Cumisky Kelly
# 3                             iMove
# 4                Rooney Auctioneers
#
#                                  GroupAddress  \
# 0      27/28 Marino Mart, Fairview, Dublin 3
# 1               50 South Mall, Cork, T12 ND73
# 2  21 Drogheda Street, Balbriggan, Co. Dublin
# 3                       10 Fairview, Dublin 3
# 4               99 O'Connell Street, Limerick
#
#                        CreatedOnDate                        ActivatedOn  \
# 0  2022-09-15T14:29:33.9530000+01:00  2022-09-15T14:45:41.1900000+01:00
# 1  2022-07-14T11:36:39.1670000+01:00  2022-07-14T11:43:26.0470000+01:00
# 2  2022-08-23T16:26:25.2400000+01:00  2022-08-23T16:42:47.6770000+01:00
# 3  2021-12-15T16:21:22.1630000+00:00  2021-12-15T16:28:29.3270000+00:00
# 4  2022-10-03T10:26:17.6930000+01:00  2022-10-18T16:09:28.9730000+01:00
#
#    IsActive PropertyStatus PropertyType
# 0      True        ForSale    Townhouse
# 1      True        ForSale    Townhouse
# 2      True        ForSale    Townhouse
# 3      True        ForSale    Townhouse
# 4      True        ForSale    Townhouse

# %%
#Establish in mongodb 
# importing the library
import pandas as pd
import pymongo
import urllib
from pymongo import MongoClient

# %%
# Load csv dataset
df.to_csv('myhome.csv')

# %%
data = pd.read_csv('myhome.csv')

# %%
#Connect to MongoDB
client = pymongo.MongoClient("mongodb://Divya:"+ urllib.parse.quote_plus("Divya@0209")+"@ac-ftrsqrg-shard-00-00.xe4uins.mongodb.net:27017,ac-ftrsqrg-shard-00-01.xe4uins.mongodb.net:27017,ac-ftrsqrg-shard-00-02.xe4uins.mongodb.net:27017/?ssl=true&replicaSet=atlas-e5bv9c-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.test

# %%
# insert name of database and name of collection
db = client['myhome']
collection = db['myhomecollection']

# %%
data.reset_index(inplace=True)

# %%
#insert collection
db.collection.insert_many(df.to_dict('records'))
